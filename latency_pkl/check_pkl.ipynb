# %%
import pickle

with open('./peak_memory_cpu.pkl', 'rb') as f:
	peak_memory_lookup = pickle.load(f)

# %%
peak_memory_lookup
# Out:
# OrderedDict([('MBInvertedResBlock_112_16_0_24_k3_s2_relu',
#               OrderedDict([(16, 0.777587890625),
#                            (17, 1.5791015625),
#                            (18, 1.626953125),
#                            (19, 1.6748046875),
#                            (20, 1.72265625),
#                            (21, 1.7705078125),
#                            (22, 1.818359375),
#                            (23, 1.8662109375),
#                            (24, 1.9140625),
#                            (25, 1.9619140625),
#                            (26, 2.009765625),
#                            (27, 2.0576171875),
#                            (28, 2.10546875),
#                            (29, 2.1533203125),
#                            (30, 2.201171875),
#                            (31, 2.2490234375),
#                            (32, 2.296875),
#                            (33, 2.3447265625),
#                            (34, 2.392578125),
# ...
